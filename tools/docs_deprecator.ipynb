# %%
from bs4 import BeautifulSoup as BS
import os
from pathlib import Path

# %%
def adjust(root, file, dry = False):
    '''
    mark an html file deprecated, incl' canonical link for crawlers.
    dry: do not overwrite, but go to temp file.
    '''
    base = Path(root)
    # if (Path(file).suffix != '.html') raise ValueError("Not an html file.")
    if ('.tmp' in Path(file).suffixes): return # prefer to ignore own temp files.
    
    with open(base / file, "rt") as f:
        parse = BS(f, 'lxml')
        for child in parse.html.children: # beautifulsoup likes explicit iteration
            
            if child.name == 'head':
                ver, *rest = base.parts # '/'.join(rest) is our best-guess current version.
                target = os.path.join('https://matplotlib.org', *rest, file)
                    # ADJUST as necessary.
                    # Base path contains version string, so '..' is wrong.
                    
                redirect_bots = \
                    BS('''<link href="{}" rel="canonical">'''.format(target), 'html.parser')
                    # lxml would wrap this snippet. yuck.
                child.append(redirect_bots)

            elif child.name == 'body':
                banner = BS('''<div id="old-version-banner">
            You are reading documentation for a static version of Matplotlib.
            <a href="{}">This page may have been updated.</a>
            </div>'''.format(target), 'html.parser')
                child.insert(0, banner)

        *name, ext = file.split('.')
        dummy = ('.'.join([*name, 'tmp', ext]))
                # file if (name[-1] == 'tmp') else
        
        with open(base/dummy if dry else base/file, "wt") as g:
            g.write(str(parse))

# %%
import profile

pr = profile.Profile()
pr.run("adjust(Path('./2.0.2'), 'index.html', dry=True)")
pr.create_stats()
pr.print_stats(sort=1) # want to initialize lxml only once!
# Out:
#          17847 function calls (17501 primitive calls) in 0.063 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     167/1    0.006    0.000    0.021    0.021 element.py:1119(decode)
#         1    0.004    0.004    0.035    0.035 _lxml.py:246(feed)
# 2410/2402    0.003    0.000    0.004    0.000 :0(isinstance)
#       161    0.003    0.000    0.019    0.000 _lxml.py:145(start)
#       499    0.003    0.000    0.010    0.000 __init__.py:337(endData)
#     167/1    0.003    0.000    0.021    0.021 element.py:1218(decode_contents)
#      2053    0.002    0.000    0.002    0.000 :0(append)
#       167    0.002    0.000    0.006    0.000 element.py:813(__init__)
#       281    0.002    0.000    0.004    0.000 __init__.py:367(object_was_parsed)
#       729    0.002    0.000    0.002    0.000 element.py:203(setup)
#       115    0.002    0.000    0.003    0.000 __init__.py:152(_replace_cdata_list_attribute_values)
#       164    0.002    0.000    0.014    0.000 __init__.py:447(handle_starttag)
#       862    0.001    0.000    0.001    0.000 :0(len)
#       281    0.001    0.000    0.003    0.000 element.py:704(__new__)
#       161    0.001    0.000    0.009    0.000 _lxml.py:194(end)
#       467    0.001    0.000    0.003    0.000 element.py:106(_substitute_if_appropriate)
#       467    0.001    0.000    0.006    0.000 element.py:160(format_string)
#       164    0.001    0.000    0.002    0.000 __init__.py:424(_popToTag)
#       763    0.001    0.000    0.001    0.000 :0(join)
#       809    0.001    0.000    0.001    0.000 :0(callable)
#         2    0.001    0.001    0.001    0.001 :0(open)
#       167    0.001    0.000    0.001    0.000 __init__.py:328(pushTag)
#       164    0.001    0.000    0.003    0.000 __init__.py:474(handle_endtag)
#       467    0.001    0.000    0.004    0.000 element.py:121(substitute_xml)
#       461    0.001    0.000    0.001    0.000 :0(sub)
#       460    0.001    0.000    0.002    0.000 dammit.py:139(substitute_xml)
#       287    0.001    0.000    0.001    0.000 _lxml.py:215(data)
#       283    0.001    0.000    0.001    0.000 :0(items)
#       277    0.001    0.000    0.004    0.000 element.py:739(output_ready)
#       504    0.001    0.000    0.001    0.000 _lxml.py:76(_getNsTag)
#       293    0.001    0.000    0.001    0.000 __init__.py:479(handle_data)
#       289    0.000    0.000    0.000    0.000 :0(__new__)
#       242    0.000    0.000    0.000    0.000 :0(get)
#       164    0.000    0.000    0.001    0.000 __init__.py:319(popTag)
#         1    0.000    0.000    0.063    0.063 profile:0(adjust(Path('./2.0.2'), 'index.html', dry=True))
#         1    0.000    0.000    0.000    0.000 :0(read)
#       115    0.000    0.000    0.000    0.000 :0(sorted)
#       167    0.000    0.000    0.000    0.000 __init__.py:267(set_up_substitutions)
#       167    0.000    0.000    0.000    0.000 :0(pop)
#         5    0.000    0.000    0.000    0.000 pathlib.py:51(parse_parts)
#         1    0.000    0.000    0.062    0.062 <ipython-input-2-2f7d0231d7b5>:1(adjust)
#       336    0.000    0.000    0.000    0.000 element.py:1024(__bool__)
#       170    0.000    0.000    0.000    0.000 element.py:880(is_empty_element)
#        37    0.000    0.000    0.000    0.000 :0(split)
#         3    0.000    0.000    0.038    0.013 __init__.py:87(__init__)
#       167    0.000    0.000    0.000    0.000 __init__.py:108(can_be_empty_element)
#         1    0.000    0.000    0.062    0.062 :0(exec)
#       167    0.000    0.000    0.000    0.000 element.py:1013(__iter__)
#         5    0.000    0.000    0.001    0.000 pathlib.py:629(_parse_args)
#       186    0.000    0.000    0.000    0.000 dammit.py:102(quoted_attribute_value)
#       127    0.000    0.000    0.000    0.000 :0(lower)
#       115    0.000    0.000    0.000    0.000 :0(keys)
#       161    0.000    0.000    0.000    0.000 _lxml.py:185(_prefix_for_namespace)
#         1    0.000    0.000    0.000    0.000 inspect.py:2095(_signature_from_function)
#        49    0.000    0.000    0.000    0.000 _collections_abc.py:672(keys)
#       167    0.000    0.000    0.000    0.000 element.py:1111(_should_pretty_print)
#         3    0.000    0.000    0.001    0.000 parser.py:301(parse_starttag)
#       168    0.000    0.000    0.000    0.000 :0(iter)
#         1    0.000    0.000    0.001    0.001 inspect.py:1082(getfullargspec)
#         3    0.000    0.000    0.001    0.000 pathlib.py:649(_from_parts)
#         3    0.000    0.000    0.001    0.000 pathlib.py:976(__new__)
#       2/1    0.000    0.000    0.001    0.001 inspect.py:2176(_signature_from_callable)
#         6    0.000    0.000    0.001    0.000 element.py:518(_find_all)
#         3    0.000    0.000    0.000    0.000 __init__.py:42(lookup)
#        49    0.000    0.000    0.000    0.000 _collections_abc.py:719(__iter__)
#         2    0.000    0.000    0.001    0.001 parser.py:134(goahead)
#       3/2    0.000    0.000    0.000    0.000 abc.py:194(__subclasscheck__)
#         6    0.000    0.000    0.000    0.000 element.py:1585(__init__)
#         1    0.000    0.000    0.000    0.000 :0(warn)
#         1    0.000    0.000    0.000    0.000 :0(setprofile)
#         4    0.000    0.000    0.000    0.000 inspect.py:2434(__init__)
#        20    0.000    0.000    0.000    0.000 :0(match)
#         1    0.000    0.000    0.062    0.062 <string>:1(<module>)
#        13    0.000    0.000    0.000    0.000 element.py:1612(_normalize_search_value)
#         3    0.000    0.000    0.000    0.000 __init__.py:295(reset)
#         6    0.000    0.000    0.001    0.000 element.py:1043(__getattr__)
#         1    0.000    0.000    0.000    0.000 :0(write)
#         3    0.000    0.000    0.000    0.000 abc.py:178(__instancecheck__)
#        49    0.000    0.000    0.000    0.000 _collections_abc.py:698(__init__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2713(__init__)
#         6    0.000    0.000    0.001    0.000 element.py:1298(find_all)
#         2    0.000    0.000    0.000    0.000 pathlib.py:683(_make_child)
#         5    0.000    0.000    0.000    0.000 :0(intern)
#        14    0.000    0.000    0.000    0.000 :0(hasattr)
#         1    0.000    0.000    0.001    0.001 inspect.py:1051(getargspec)
#         1    0.000    0.000    0.000    0.000 pathlib.py:793(suffixes)
#         5    0.000    0.000    0.000    0.000 pathlib.py:282(splitroot)
#         1    0.000    0.000    0.000    0.000 _lxml.py:57(parser_for)
#         8    0.000    0.000    0.000    0.000 :0(reverse)
#        12    0.000    0.000    0.000    0.000 _weakrefset.py:70(__contains__)
#         6    0.000    0.000    0.001    0.000 element.py:1287(find)
#         8    0.000    0.000    0.000    0.000 :0(search)
#         3    0.000    0.000    0.037    0.012 __init__.py:285(_feed)
#         1    0.000    0.000    0.000    0.000 _lxml.py:218(doctype)
#         2    0.000    0.000    0.000    0.000 element.py:310(insert)
#         5    0.000    0.000    0.000    0.000 pathlib.py:986(_init)
#         5    0.000    0.000    0.000    0.000 inspect.py:2758(<genexpr>)
#        10    0.000    0.000    0.000    0.000 _markupbase.py:48(updatepos)
#         7    0.000    0.000    0.000    0.000 :0(next)
#         2    0.000    0.000    0.000    0.000 pathlib.py:689(__str__)
#         2    0.000    0.000    0.000    0.000 parser.py:386(parse_endtag)
#         2    0.000    0.000    0.000    0.000 pathlib.py:662(_from_parsed_parts)
#         3    0.000    0.000    0.000    0.000 _lxml.py:223(comment)
#        11    0.000    0.000    0.000    0.000 :0(endswith)
#         1    0.000    0.000    0.000    0.000 element.py:793(for_name_and_ids)
#         6    0.000    0.000    0.000    0.000 element.py:1801(__init__)
#        14    0.000    0.000    0.000    0.000 :0(group)
#         2    0.000    0.000    0.000    0.000 _lxml.py:84(prepare_markup)
#         8    0.000    0.000    0.000    0.000 element.py:1323(descendants)
#         5    0.000    0.000    0.000    0.000 :0(fspath)
#         1    0.000    0.000    0.000    0.000 codecs.py:318(decode)
#         3    0.000    0.000    0.000    0.000 _htmlparser.py:79(handle_starttag)
#         2    0.000    0.000    0.000    0.000 _bootlocale.py:23(getpreferredencoding)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:406(__subclasshook__)
#         1    0.000    0.000    0.000    0.000 :0(utf_8_decode)
#        14    0.000    0.000    0.000    0.000 :0(startswith)
#         3    0.000    0.000    0.000    0.000 _collections_abc.py:72(_check_methods)
#         2    0.000    0.000    0.000    0.000 pathlib.py:894(__truediv__)
#       3/1    0.000    0.000    0.021    0.021 __init__.py:482(decode)
#        12    0.000    0.000    0.000    0.000 :0(end)
#         3    0.000    0.000    0.000    0.000 _weakrefset.py:81(add)
#         2    0.000    0.000    0.000    0.000 :0(nl_langinfo)
#         2    0.000    0.000    0.000    0.000 pathlib.py:699(__fspath__)
#         1    0.000    0.000    0.000    0.000 element.py:1648(search_tag)
#         8    0.000    0.000    0.000    0.000 inspect.py:2483(name)
#         1    0.000    0.000    0.000    0.000 _lxml.py:66(__init__)
#         4    0.000    0.000    0.000    0.000 :0(isidentifier)
#         2    0.000    0.000    0.000    0.000 pathlib.py:672(_format_parsed_parts)
#         1    0.000    0.000    0.000    0.000 codecs.py:308(__init__)
#         3    0.000    0.000    0.000    0.000 parser.py:352(check_for_whole_start_tag)
#         6    0.000    0.000    0.000    0.000 __init__.py:129(deprecated_argument)
#         1    0.000    0.000    0.000    0.000 element.py:1715(_matches)
#         4    0.000    0.000    0.000    0.000 element.py:296(_last_descendant)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:58(__iter__)
#         3    0.000    0.000    0.000    0.000 element.py:989(get)
#         1    0.000    0.000    0.000    0.000 element.py:74(__new__)
#         2    0.000    0.000    0.000    0.000 element.py:1689(search)
#         8    0.000    0.000    0.000    0.000 :0(count)
#         4    0.000    0.000    0.000    0.000 element.py:758(output_ready)
#         2    0.000    0.000    0.000    0.000 <string>:12(__new__)
#         2    0.000    0.000    0.000    0.000 inspect.py:159(isfunction)
#         1    0.000    0.000    0.000    0.000 pathlib.py:775(name)
#         2    0.000    0.000    0.001    0.001 _htmlparser.py:210(feed)
#       3/2    0.000    0.000    0.000    0.000 typing.py:1145(__subclasscheck__)
#         4    0.000    0.000    0.000    0.000 dammit.py:95(_substitute_xml_entity)
#         6    0.000    0.000    0.000    0.000 __init__.py:105(reset)
#       3/2    0.000    0.000    0.000    0.000 :0(issubclass)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#         2    0.000    0.000    0.000    0.000 pathlib.py:89(join_parsed_parts)
#         4    0.000    0.000    0.000    0.000 _htmlparser.py:192(prepare_markup)
#         5    0.000    0.000    0.000    0.000 inspect.py:2487(default)
#         1    0.000    0.000    0.000    0.000 :0(values)
#         1    0.000    0.000    0.000    0.000 posixpath.py:73(join)
#         2    0.000    0.000    0.001    0.001 parser.py:104(feed)
#         1    0.000    0.000    0.000    0.000 pathlib.py:800(<listcomp>)
#         2    0.000    0.000    0.000    0.000 _htmlparser.py:56(__init__)
#         1    0.000    0.000    0.000    0.000 typing.py:875(__extrahook__)
#         1    0.000    0.000    0.000    0.000 _lxml.py:243(default_parser)
#         3    0.000    0.000    0.000    0.000 _htmlparser.py:107(handle_endtag)
#         5    0.000    0.000    0.000    0.000 :0(start)
#         2    0.000    0.000    0.000    0.000 parser.py:96(reset)
#         4    0.000    0.000    0.000    0.000 inspect.py:2495(kind)
#         5    0.000    0.000    0.000    0.000 :0(add)
#         4    0.000    0.000    0.000    0.000 inspect.py:2491(annotation)
#         1    0.000    0.000    0.000    0.000 codecs.py:259(__init__)
#         2    0.000    0.000    0.000    0.000 :0(format)
#         3    0.000    0.000    0.000    0.000 _htmlparser.py:118(handle_data)
#         1    0.000    0.000    0.000    0.000 element.py:194(_formatter_for_name)
#         8    0.000    0.000    0.000    0.000 element.py:743(name)
#         1    0.000    0.000    0.000    0.000 :0(lstrip)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#         1    0.000    0.000    0.000    0.000 element.py:376(append)
#         1    0.000    0.000    0.000    0.000 pathlib.py:874(parts)
#         2    0.000    0.000    0.000    0.000 parser.py:87(__init__)
#         1    0.000    0.000    0.021    0.021 element.py:1091(__unicode__)
#         4    0.000    0.000    0.000    0.000 __init__.py:122(unescape)
#         3    0.000    0.000    0.000    0.000 :0(strip)
#         3    0.000    0.000    0.000    0.000 :0(__subclasses__)
#         2    0.000    0.000    0.000    0.000 :0(min)
#         2    0.000    0.000    0.000    0.000 _htmlparser.py:185(__init__)
#         2    0.000    0.000    0.000    0.000 :0(insert)
#         2    0.000    0.000    0.000    0.000 typing.py:1019(_abc_negative_cache)
#         2    0.000    0.000    0.000    0.000 typing.py:1089(__eq__)
#         1    0.000    0.000    0.000    0.000 typing.py:1033(_abc_negative_cache_version)
#         2    0.000    0.000    0.000    0.000 :0(rindex)
#         1    0.000    0.000    0.000    0.000 element.py:84(encode)
#         1    0.000    0.000    0.000    0.000 element.py:1028(__setitem__)
#         1    0.000    0.000    0.000    0.000 _lxml.py:142(close)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#         2    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         2    0.000    0.000    0.000    0.000 _markupbase.py:36(reset)
#         1    0.000    0.000    0.000    0.000 inspect.py:2788(parameters)
#         2    0.000    0.000    0.000    0.000 :0(getattr)
#         1    0.000    0.000    0.000    0.000 inspect.py:2792(return_annotation)
#         2    0.000    0.000    0.000    0.000 :0(_getframe)
#         1    0.000    0.000    0.000    0.000 codecs.py:185(__init__)
#         2    0.000    0.000    0.000    0.000 :0(remove)
#         1    0.000    0.000    0.000    0.000 element.py:85(rewrite)
#         2    0.000    0.000    0.000    0.000 parser.py:127(clear_cdata_mode)
#         1    0.000    0.000    0.000    0.000 posixpath.py:39(_get_sep)
#         1    0.000    0.000    0.000    0.000 element.py:1318(children)
#         1    0.000    0.000    0.000    0.000 element.py:170(_is_xml)
#         0    0.000             0.000          profile:0(profiler)

# %%
# base, file = Path('./2.0.2/api'), 'pyplot_summary.html'
# with open(base / file, "rt") as f:
#    parse = BS(f, 'lxml')

# %%
def process(target, verbose = False, dry = False):
    delve = ''; deeper = ''
    for root, _, files in os.walk(Path(target)):
        path = Path(root)

        # progress meter, inspired loosely by https://stackoverflow.com/a/2165062
        if verbose:
            try:
                s = path.parts[1] # toplevel.index()
                if s != delve:
                    delve = s; print(s)
                else:
                    r = path.parts[2] if s not in ['mpl_examples', 'examples'] else '...'
                    if r != deeper:
                        deeper = r; print('\t' + r)
            except: pass

        for f in files:
            try:
                # expect .pdf, .png, .py files. ignore them.
                if (Path(f).suffix == '.html'):
                    adjust(path, f, False) # time.sleep(.0001)

            except UnicodeDecodeError as e:
                print(f, e)
            except AttributeError as e:
                print(f, e)

# %%
# test on a single legacy site
# ! svn checkout https://github.com/matplotlib/matplotlib.github.com/trunk/2.0.2
# process('2.0.2', dry=True)

# %%
import re
targets = [d for d in os.listdir() if re.match(r'''\d+\.\d+\.\d+''', d)]
targets

# Below cell will mutate all HTML files in the directories listed.
# Out:
# ['1.4.0',
#  '1.2.1',
#  '1.5.0',
#  '2.0.2',
#  '2.1.1',
#  '2.0.0',
#  '1.4.3',
#  '2.0.1',
#  '1.4.1',
#  '1.3.1',
#  '2.2.0',
#  '1.5.1',
#  '2.2.2',
#  '1.5.3',
#  '2.1.0',
#  '1.3.0',
#  '2.1.2',
#  '1.4.2']

# %%
# run me as code cell to proceed.
for t in targets: process(t, verbose=True)
# Out:
# mpl_toolkits
# 	mplot3d
# 	axes_grid
# api
# faq
# devel
# 	gitwash
# _sources
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	examples
# 	users
# 	resources
# glossary
# mpl_examples
# 	...
# pyplots
# plot_directive
# 	mpl_examples
# examples
# 	...
# _images
# 	mathmpl
# users
# 	plotting
# _static
# resources
# mpl_toolkits
# 	mplot3d
# 	axes_grid
# api
# faq
# devel
# 	gitwash
# _sources
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	examples
# 	users
# glossary
# mpl_examples
# 	...
# pyplots
# plot_directive
# 	mpl_examples
# examples
# 	...
# _images
# 	mathmpl
# users
# 	plotting
# _static
# mpl_toolkits
# 	mplot3d
# 	axes_grid
# api
# faq
# devel
# 	gitwash
# 	MEP
# _sources
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	examples
# 	users
# 	resources
# glossary
# mpl_examples
# 	...
# pyplots
# plot_directive
# 	mpl_examples
# examples
# 	...
# _images
# 	mathmpl
# users
# 	plotting
# _static
# resources
# mpl_toolkits
# 	mplot3d
# 	axes_grid
# api
# 	_as_gen
# faq
# devel
# 	gitwash
# 	MEP
# _sources
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	examples
# 	users
# 	resources
# glossary
# mpl_examples
# 	...
# plot_directive
# 	mpl_examples
# examples
# 	...
# _images
# 	mathmpl
# users
# 	plotting
# 	prev_whats_new
# _static
# resources
# gallery
# 	recipes
# 	units
# 	axisartist
# 	api
# 	pie_and_polar_charts
# 	misc
# 	statistics
# 	widgets
# 	user_interfaces
# 	animation
# 	frontpage
# 	images_contours_and_fields
# 	userdemo
# 	shapes_and_collections
# 	subplots_axes_and_figures
# 	specialty_plots
# 	scales
# 	pyplots
# 	lines_bars_and_markers
# 	style_sheets
# 	ticks_and_spines
# 	mplot3d
# 	text_labels_and_annotations
# 	event_handling
# 	showcase
# 	color
# 	axes_grid1
# mpl_toolkits
# 	axisartist
# 	mplot3d
# 	axes_grid1
# api
# 	_as_gen
# 	toolkits
# faq
# _downloads
# devel
# 	gitwash
# 	MEP
# _sources
# 	gallery
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	users
# 	tutorials
# 	thirdpartypackages
# 	resources
# glossary
# mpl_examples
# 	...
# _images
# 	mathmpl
# users
# 	prev_whats_new
# _static
# tutorials
# 	introductory
# 	intermediate
# 	advanced
# 	text
# 	toolkits
# 	colors
# thirdpartypackages
# resources
# mpl_toolkits
# 	mplot3d
# 	axes_grid
# api
# 	_as_gen
# faq
# devel
# 	gitwash
# 	MEP
# _sources
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	examples
# 	users
# 	resources
# glossary
# mpl_examples
# 	...
# plot_directive
# 	mpl_examples
# examples
# 	...
# _images
# 	mathmpl
# users
# 	plotting
# 	prev_whats_new
# _static
# resources
# mpl_toolkits
# 	mplot3d
# 	axes_grid
# api
# faq
# devel
# 	gitwash
# _sources
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	examples
# 	users
# 	resources
# glossary
# mpl_examples
# 	...
# pyplots
# plot_directive
# 	mpl_examples
# examples
# 	...
# _images
# 	mathmpl
# users
# 	plotting
# _static
# resources
# mpl_toolkits
# 	mplot3d
# 	axes_grid
# api
# 	_as_gen
# faq
# devel
# 	gitwash
# 	MEP
# _sources
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	examples
# 	users
# 	resources
# glossary
# mpl_examples
# 	...
# plot_directive
# 	mpl_examples
# examples
# 	...
# _images
# 	mathmpl
# users
# 	plotting
# 	prev_whats_new
# _static
# resources
# mpl_toolkits
# 	mplot3d
# 	axes_grid
# api
# faq
# devel
# 	gitwash
# _sources
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	examples
# 	users
# 	resources
# glossary
# mpl_examples
# 	...
# pyplots
# plot_directive
# 	mpl_examples
# examples
# 	...
# _images
# 	mathmpl
# users
# 	plotting
# _static
# resources
# mpl_toolkits
# 	mplot3d
# 	axes_grid
# api
# faq
# devel
# 	gitwash
# _sources
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	examples
# 	users
# glossary
# mpl_examples
# 	...
# pyplots
# plot_directive
# 	mpl_examples
# examples
# 	...
# _images
# 	mathmpl
# users
# 	plotting
# _static
# gallery
# 	recipes
# 	units
# 	axisartist
# 	api
# 	pie_and_polar_charts
# 	misc
# 	statistics
# 	widgets
# 	user_interfaces
# 	animation
# 	frontpage
# 	images_contours_and_fields
# 	userdemo
# 	shapes_and_collections
# 	subplots_axes_and_figures
# 	specialty_plots
# 	scales
# 	pyplots
# 	lines_bars_and_markers
# 	style_sheets
# 	ticks_and_spines
# 	mplot3d
# 	text_labels_and_annotations
# 	event_handling
# 	showcase
# 	color
# 	axes_grid1
# mpl_toolkits
# 	axisartist
# 	mplot3d
# 	axes_grid1
# api
# 	_as_gen
# 	next_api_changes
# 	toolkits
# faq
# _downloads
# devel
# 	gitwash
# 	MEP
# _sources
# 	gallery
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	users
# 	tutorials
# 	thirdpartypackages
# 	resources
# glossary
# _images
# 	mathmpl
# users
# 	next_whats_new
# 	prev_whats_new
# _static
# tutorials
# 	introductory
# 	intermediate
# 	advanced
# 	text
# 	toolkits
# 	colors
# thirdpartypackages
# resources
# mpl_toolkits
# 	mplot3d
# 	axes_grid
# api
# faq
# devel
# 	gitwash
# 	MEP
# _sources
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	examples
# 	users
# 	resources
# glossary
# mpl_examples
# 	...
# pyplots
# plot_directive
# 	mpl_examples
# examples
# 	...
# _images
# 	mathmpl
# users
# 	plotting
# _static
# resources
# gallery
# 	recipes
# 	units
# 	axisartist
# 	api
# 	pie_and_polar_charts
# 	misc
# 	statistics
# 	widgets
# 	user_interfaces
# 	animation
# 	frontpage
# 	images_contours_and_fields
# 	userdemo
# 	shapes_and_collections
# 	subplots_axes_and_figures
# 	specialty_plots
# 	scales
# 	pyplots
# 	lines_bars_and_markers
# 	style_sheets
# 	ticks_and_spines
# 	mplot3d
# 	text_labels_and_annotations
# 	event_handling
# 	showcase
# 	color
# 	axes_grid1
# mpl_toolkits
# 	axisartist
# 	mplot3d
# 	axes_grid1
# api
# 	_as_gen
# 	next_api_changes
# 	toolkits
# faq
# _downloads
# devel
# 	gitwash
# 	MEP
# _sources
# 	gallery
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	users
# 	tutorials
# 	thirdpartypackages
# 	resources
# glossary
# _images
# 	mathmpl
# users
# 	next_whats_new
# 	prev_whats_new
# _static
# tutorials
# 	introductory
# 	intermediate
# 	advanced
# 	text
# 	toolkits
# 	colors
# thirdpartypackages
# _modules
# 	mpl_toolkits
# 	dateutil
# 	matplotlib
# resources
# mpl_toolkits
# 	mplot3d
# 	axes_grid
# api
# faq
# devel
# 	gitwash
# 	MEP
# _sources
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	examples
# 	users
# 	resources
# glossary
# mpl_examples
# 	...
# pyplots
# plot_directive
# 	mpl_examples
# examples
# 	...
# _images
# 	mathmpl
# users
# 	plotting
# _static
# resources
# gallery
# 	recipes
# 	units
# 	axisartist
# 	api
# 	pie_and_polar_charts
# 	misc
# 	statistics
# 	widgets
# 	user_interfaces
# 	animation
# 	frontpage
# 	images_contours_and_fields
# 	userdemo
# 	shapes_and_collections
# 	subplots_axes_and_figures
# 	specialty_plots
# 	scales
# 	pyplots
# 	lines_bars_and_markers
# 	style_sheets
# 	ticks_and_spines
# 	mplot3d
# 	text_labels_and_annotations
# 	event_handling
# 	showcase
# 	color
# 	axes_grid1
# mpl_toolkits
# 	axisartist
# 	mplot3d
# 	axes_grid1
# api
# 	_as_gen
# 	toolkits
# faq
# _downloads
# devel
# 	gitwash
# 	MEP
# _sources
# 	gallery
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	users
# 	tutorials
# 	thirdpartypackages
# 	resources
# glossary
# mpl_examples
# 	...
# _images
# 	mathmpl
# users
# 	prev_whats_new
# _static
# tutorials
# 	introductory
# 	intermediate
# 	advanced
# 	text
# 	toolkits
# 	colors
# thirdpartypackages
# resources
# mpl_toolkits
# 	mplot3d
# 	axes_grid
# api
# faq
# devel
# 	gitwash
# _sources
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	examples
# 	users
# glossary
# mpl_examples
# 	...
# pyplots
# plot_directive
# 	mpl_examples
# examples
# 	...
# _images
# 	mathmpl
# users
# 	plotting
# _static
# gallery
# 	recipes
# 	units
# 	axisartist
# 	api
# 	pie_and_polar_charts
# 	misc
# 	statistics
# 	widgets
# 	user_interfaces
# 	animation
# 	frontpage
# 	images_contours_and_fields
# 	userdemo
# 	shapes_and_collections
# 	subplots_axes_and_figures
# 	specialty_plots
# 	scales
# 	pyplots
# 	lines_bars_and_markers
# 	style_sheets
# 	ticks_and_spines
# 	mplot3d
# 	text_labels_and_annotations
# 	event_handling
# 	showcase
# 	color
# 	axes_grid1
# mpl_toolkits
# 	axisartist
# 	mplot3d
# 	axes_grid1
# api
# 	_as_gen
# 	toolkits
# faq
# _downloads
# devel
# 	gitwash
# 	MEP
# _sources
# 	gallery
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	users
# 	tutorials
# 	thirdpartypackages
# 	resources
# glossary
# mpl_examples
# 	...
# _images
# 	mathmpl
# users
# 	prev_whats_new
# _static
# tutorials
# 	introductory
# 	intermediate
# 	advanced
# 	text
# 	toolkits
# 	colors
# thirdpartypackages
# resources
# mpl_toolkits
# 	mplot3d
# 	axes_grid
# api
# faq
# devel
# 	gitwash
# _sources
# 	mpl_toolkits
# 	api
# 	faq
# 	devel
# 	glossary
# 	examples
# 	users
# 	resources
# glossary
# mpl_examples
# 	...
# pyplots
# plot_directive
# 	mpl_examples
# examples
# 	...
# _images
# 	mathmpl
# users
# 	plotting
# _static
# resources
